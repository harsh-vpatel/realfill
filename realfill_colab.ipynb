# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/3010_realfill
# !ls
# Out:
# /content/drive/MyDrive/3010_realfill
# eval.py        README.md	       runs
# infer_base.py  realfill_dataset        train_realfill.ipynb
# infer.py       requirements_colab.txt  train_realfill_original.py
# LICENSE        requirements.txt        train_realfill.py

# %%
# !cp requirements.txt requirements_colab.txt
# !echo "numpy==1.26.4" | cat - requirements_colab.txt > tmp && mv tmp requirements_colab.txt
# !cat requirements_colab.txt
# Out:
# numpy==1.26.4
# diffusers==0.20.1
# accelerate==0.23.0
# transformers==4.36.0
# peft==0.5.0
# huggingface-hub==0.25.2
# torch==2.0.1
# torchvision==0.15.2
# ftfy==6.1.1
# tensorboard==2.14.0
# Jinja2==3.1.3

# %%
import sys
import torch
import torchvision
import numpy
import diffusers
import transformers
import accelerate
import huggingface_hub
import peft
import tensorboard
import jinja2

print("Python:", sys.version)
print("torch:", torch.__version__)
print("torchvision:", torchvision.__version__)
print("numpy:", numpy.__version__)
print("diffusers:", diffusers.__version__)
print("transformers:", transformers.__version__)
print("accelerate:", accelerate.__version__)
print("huggingface_hub:", huggingface_hub.__version__)
print("peft:", peft.__version__)
print("tensorboard:", tensorboard.__version__)
print("Jinja2:", jinja2.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# Python: 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# torch: 2.6.0+cu124
# torchvision: 0.21.0+cu124
# numpy: 2.0.2
# diffusers: 0.34.0
# transformers: 4.53.2
# accelerate: 1.8.1
# huggingface_hub: 0.33.4
# peft: 0.16.0
# tensorboard: 2.18.0
# Jinja2: 3.1.6
# CUDA available: True
# GPU: Tesla T4

# %%
from accelerate.utils import write_basic_config
write_basic_config()
# Out:
# PosixPath('/root/.cache/huggingface/accelerate/default_config.yaml')

# %%
# !accelerate launch train_realfill.py \
  --pretrained_model_name_or_path="sd2-community/stable-diffusion-2-inpainting" \
  --train_data_dir="/content/drive/MyDrive/3010_realfill/realfill_dataset/RealBench/10" \
  --output_dir="/content/drive/MyDrive/3010_realfill/runs/bench10-model" \
  --resolution=512 \
  --train_batch_size=16 \
  --gradient_accumulation_steps=1 \
  --mixed_precision=fp16 \
  --allow_tf32 \
  --gradient_checkpointing \
  --set_grads_to_none \
  --unet_learning_rate=2e-4 \
  --text_encoder_learning_rate=4e-5 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=100 \
  --max_train_steps=2000 \
  --validation_steps=100 \
  --num_validation_images=1 \
  --checkpointing_steps=100 \
  --lora_rank=8 \
  --lora_dropout=0.1 \
  --lora_alpha=16 \
  --prompt_dropout_prob=0.1 \
  --mask_dropout_prob=0.1
  #--resume_from_checkpoint="latest"
# Out:
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2026-04-25 04:36:41.109031: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777091801.145808     855 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777091801.156002     855 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# tokenizer_config.json: 100% 829/829 [00:00<00:00, 7.34MB/s]
# vocab.json: 1.06MB [00:00, 37.6MB/s]
# merges.txt: 525kB [00:00, 124MB/s]
# special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.97MB/s]
# ...
